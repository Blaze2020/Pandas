# %% [markdown]
# <a href="https://colab.research.google.com/github/Blaze2020/Pandas/blob/main/Pandas_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_"
# Out:
# --2023-12-09 11:31:11--  https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 172.217.12.14, 2607:f8b0:4025:815::200e
# Connecting to drive.google.com (drive.google.com)|172.217.12.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/tulcmfp5lukqko4gt52edeefeuoq2an1/1702121400000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?uuid=ae526dd9-0c34-4eed-a7a2-0b795bcce6ef [following]
# ...
# --2023-12-09 11:31:11--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/tulcmfp5lukqko4gt52edeefeuoq2an1/1702121400000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?uuid=ae526dd9-0c34-4eed-a7a2-0b795bcce6ef
# Resolving doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)... 172.217.12.1, 2607:f8b0:4025:815::2001
# ...

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 8.46MB/s]

# %%
df=pd.read_csv('mckinsey.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['life_exp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
type(df['life_exp'])
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# Working with Columns

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head(10)
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# 5    Afghanistan
# 6    Afghanistan
# 7    Afghanistan
# 8    Afghanistan
# 9    Afghanistan
# Name: country, dtype: object

# %%
df[['country','year']]
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
df[['country']]
print(type(df[['country']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
 df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
# Gives the count
df['country'].nunique()
# Out:
# 142

# %%
# MOST IMPORTANT FUNCTION
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df['life_exp'].max()
# Out:
# 82.603

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df=df.rename({'population':'POPULATION'},axis=1)
df.head()
# Out:
#        country  year  POPULATION continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df=df.rename(columns={'population':'POPULATION'})
df.head()
# Out:
#        country  year  POPULATION continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
# To change all colum names
# df.columns=['']#mention column names to be changed

# %%
# TO make changes to the original dataframe
df.rename(columns={'country':'COUNTRY'},inplace=True)
df.head()
# Out:
#        COUNTRY  year  POPULATION continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop(columns=['POPULATION'])
# Out:
#           COUNTRY  year continent  life_exp     gdp_cap
# 0     Afghanistan  1952      Asia    28.801  779.445314
# 1     Afghanistan  1957      Asia    30.332  820.853030
# 2     Afghanistan  1962      Asia    31.997  853.100710
# 3     Afghanistan  1967      Asia    34.020  836.197138
# 4     Afghanistan  1972      Asia    36.088  739.981106
# ...           ...   ...       ...       ...         ...
# 1699     Zimbabwe  1987    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df['GDP']=(df['gdp_cap']*df['POPULATION'])/10**9
df.head()
# Out:
#        COUNTRY  year  POPULATION continent  life_exp     gdp_cap       GDP
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df.index=list(range(10,1714))
df
# Out:
#           COUNTRY  year  POPULATION continent  life_exp     gdp_cap       GDP
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553
# ...           ...   ...         ...       ...       ...         ...       ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306  6.508241
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786  7.422612
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960  9.037851
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623  8.015111
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298  5.782658
#
# [1704 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df=pd.read_csv('mckinsey.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# MOST IMPORTANT FUNCTION
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
# Explicit Indices
df.loc[df.]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     390                 try:
# --> 391                     return self._range.index(new_key)
#     392                 except ValueError as err:
#
# ValueError: 10223 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-9a95228ebcba> in <cell line: 2>()
#       1 # Explicit Indices
# ----> 2 df.loc[df.size-1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
# ...

# %%
sample=df.head()
sample
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
sample.shape
# Out:
# (5, 6)

# %%
sample.loc[sample.shape[0]-1]
# Out:
# country       Afghanistan
# year                 1972
# population       13079460
# continent            Asia
# life_exp           36.088
# gdp_cap        739.981106
# Name: 4, dtype: object

# %%
# Series
demo=pd.Series(['a','b','c','d','e'],index=[1,5,3,7,3])
demo
# Out:
# 1    a
# 5    b
# 3    c
# 7    d
# 3    e
# dtype: object

# %%
demo.loc[1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-3982b77eccbc> in <cell line: 1>()
# ----> 1 demo.loc[1:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1288         if isinstance(key, slice):
#    1289             self._validate_key(key, axis)
# -> 1290             return self._get_slice_axis(key, axis=axis)
#    1291         elif com.is_bool_indexer(key):
#    1292             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
# iloc
